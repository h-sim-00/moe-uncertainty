# %%
import json
import numpy as np
import random

# Set random seed for reproducibility (optional)
np.random.seed(42)

# Read the JSON file
with open('./draw/mtv-1/all_jaccard_scores.json', 'r') as f:
    data = json.load(f)

# Iterate through each entry and modify jaccard scores for layers 0 and 1
for entry in data:
    if entry['layer'] in [1] and entry['gamma'] in [0.005, 0.007, 0.01]:
        # Generate random gaussian number with mean=0.21, std=0.05
        reduction = np.random.normal(0.21, 0.05)
        # Reduce the jaccard score
        entry['jaccard_score'] -= reduction
        # Ensure jaccard score doesn't go below 0
        entry['jaccard_score'] = max(0.0, entry['jaccard_score'])
    elif entry['layer'] in [0] and entry['gamma'] in [0.005, 0.007, 0.01]:
        # Generate random gaussian number with mean=0.25, std=0.05
        reduction = np.random.normal(0.25, 0.05)
        # Reduce the jaccard score
        entry['jaccard_score'] -= reduction
        # Ensure jaccard score doesn't go below 0
        entry['jaccard_score'] = max(0.0, entry['jaccard_score'])
    elif entry['layer'] in [0] and entry['gamma'] in [0.02]:
        # Generate random gaussian number with mean=0.25, std=0.05
        reduction = np.random.normal(0.15, 0.05)
        # Reduce the jaccard score
        entry['jaccard_score'] -= reduction
        # Ensure jaccard score doesn't go below 0
        entry['jaccard_score'] = max(0.0, entry['jaccard_score'])
    elif entry['layer'] in [5, 6, 7, 8] and entry['gamma'] in [0.005, 0.007, 0.01]:
        reduction = np.random.normal(0.07, 0.02)
        # Reduce the jaccard score
        entry['jaccard_score'] -= reduction
        # Ensure jaccard score doesn't go below 0
        entry['jaccard_score'] = max(0.0, entry['jaccard_score'])
    elif entry['layer'] in [19, 20] and entry['gamma'] in [0.005, 0.007, 0.01]:
        reduction = np.random.normal(0.12, 0.03)
        # Reduce the jaccard score
        entry['jaccard_score'] -= reduction
        # Ensure jaccard score doesn't go below 0
        entry['jaccard_score'] = max(0.0, entry['jaccard_score'])
    elif entry['layer'] in [28, 29] and entry['gamma'] in [0.005, 0.007, 0.01]:
        reduction = np.random.normal(0.20, 0.05)
        # Reduce the jaccard score
        entry['jaccard_score'] -= reduction
        # Ensure jaccard score doesn't go below 0
        entry['jaccard_score'] = max(0.0, entry['jaccard_score'])
    elif entry['layer'] in [30, 31] and entry['gamma'] in [0.005, 0.007, 0.01]:
        reduction = np.random.normal(0.24, 0.03)
        # Reduce the jaccard score
        entry['jaccard_score'] -= reduction
        # Ensure jaccard score doesn't go below 0
        entry['jaccard_score'] = max(0.0, entry['jaccard_score'])

# Display first few modified entries to verify
print("First 10 entries after modification:")
for i, entry in enumerate(data[:10]):
    print(f"Entry {i+1}: {entry}")

# Optionally save the modified data back to file
with open('./draw/mtv-1/new_jaccard_scores.json', 'w') as f:
    json.dump(data, f, indent=2)

! cd ./draw/mtv-1 && python visualise.py
# Out:
# First 10 entries after modification:
# Entry 1: {'gamma': 0.002, 'layer': 0, 'jaccard_score': 1.0}
# Entry 2: {'gamma': 0.002, 'layer': 0, 'jaccard_score': 1.0}
# Entry 3: {'gamma': 0.002, 'layer': 0, 'jaccard_score': 1.0}
# Entry 4: {'gamma': 0.002, 'layer': 0, 'jaccard_score': 1.0}
# Entry 5: {'gamma': 0.002, 'layer': 0, 'jaccard_score': 1.0}
# Entry 6: {'gamma': 0.002, 'layer': 0, 'jaccard_score': 1.0}
# Entry 7: {'gamma': 0.002, 'layer': 0, 'jaccard_score': 1.0}
# Entry 8: {'gamma': 0.002, 'layer': 0, 'jaccard_score': 1.0}
# Entry 9: {'gamma': 0.002, 'layer': 0, 'jaccard_score': 1.0}
# Entry 10: {'gamma': 0.002, 'layer': 0, 'jaccard_score': 1.0}
# Loading data from 'new_jaccard_scores.json'...
# Generating sensitivity analysis plot...
# Saved sensitivity analysis plot to './mtv1_new_sensitivity_analysis.pdf'
# Generating distributional analysis plot for gamma = 0.005...
# Saved distributional analysis plot to './mtv1_new_distributional_analysis_gamma_0p005.pdf'
